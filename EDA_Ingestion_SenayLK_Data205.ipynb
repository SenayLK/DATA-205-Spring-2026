# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# #Ingestion/Exploratory Data Analysis (EDA)

# %% [markdown]
# ###Loading in and exploring the Incidents data

# %%
incidents_df = pd.read_csv('Crash_Reporting_Incidents_Data_20260407.csv') #loading in the first dataset and checking the first few lines
incidents_df.head()
# Out:
# /tmp/ipykernel_9106/1963095630.py:1: DtypeWarning: Columns (1,9,11,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   incidents_df = pd.read_csv('Crash_Reporting_Incidents_Data_20260407.csv') #loading in the first dataset and checking the first few lines
#   Report Number Local Case Number   Agency Name       ACRS Report Type  \
# 0   MCP26510051         260013422    MONTGOMERY  Property Damage Crash
# 1    EJ78880091         260013399  GAITHERSBURG  Property Damage Crash
# 2   MCP235800FK         260013346    MONTGOMERY  Property Damage Crash
# 3   MCP320000HF         260013348    MONTGOMERY  Property Damage Crash
# 4   MCP3288003G         260013298    MONTGOMERY  Property Damage Crash
#
#           Crash Date/Time Hit/Run            Route Type  \
# 0  03/28/2026 09:10:00 PM     NaN  Other Public Roadway
# 1  03/28/2026 06:52:00 PM     NaN                   NaN
# 2  03/28/2026 12:00:00 PM      No           Local Route
# 3  03/28/2026 11:27:00 AM      No                   NaN
# 4  03/27/2026 10:13:00 PM      No          County Route
#
#           Lane Direction               Lane Type Number of Lanes  ...  \
# 0             Northbound                  Lane 1               1  ...
# 1                    NaN                     NaN               0  ...
# 2              Eastbound  Lane 1, Not Applicable               1  ...
# 3                    NaN                     NaN               0  ...
# 4  Northbound, Westbound                  Lane 1               2  ...
#
#           First Harmful Event  \
# 0              Parked Vehicle
# 1              Parked Vehicle
# 2  Motor Vehicle In Transport
# 3                        Curb
# 4  Motor Vehicle In Transport
#
#                                 Second Harmful Event                 Junction  \
# 0                                     Not Applicable             Non-Junction
# 1                                                NaN                      NaN
# 2                                                NaN  Intersection or Related
# 3  Other Fixed Object (wall, building, tunnel, etc.)                      NaN
# 4                                                NaN  Intersection or Related
#
#   Intersection Type Road Alignment Road Condition  \
# 0               NaN       Straight     No Defects
# 1               NaN            NaN            NaN
# 2     Perpendicular       Straight     No Defects
# 3               NaN            NaN            NaN
# 4     Perpendicular       Straight     No Defects
#
#                                   Road Division   Latitude  Longitude  \
# 0                                   Not Divided  39.167809 -77.182975
# 1                                           NaN  39.150114 -77.191244
# 2                                   Not Divided  39.043276 -77.114795
# 3                                           NaN  39.017845 -77.208213
# 4  Divided, Raised Median (curbed), Not Divided  39.174662 -77.203578
#
#                           Location
# 0       (39.1678095, -77.18297467)
# 1      (39.15011419, -77.19124427)
# 2      (39.04327621, -77.11479486)
# 3      (39.01784503, -77.20821304)
# 4         (39.1746625, -77.203578)
#
# [5 rows x 37 columns]

# %%
incidents_df.info() #checking the dimensions and basic info on the dataset columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120440 entries, 0 to 120439
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Report Number                 120440 non-null  object
#  1   Local Case Number             120440 non-null  object
#  2   Agency Name                   120440 non-null  object
#  3   ACRS Report Type              120440 non-null  object
#  4   Crash Date/Time               120440 non-null  object
#  5   Hit/Run                       116086 non-null  object
#  6   Route Type                    104515 non-null  object
#  7   Lane Direction                105116 non-null  object
#  8   Lane Type                     29564 non-null   object
#  9   Number of Lanes               108101 non-null  object
#  10  Direction                     105174 non-null  object
#  11  Distance                      107037 non-null  object
#  12  Distance Unit                 108113 non-null  object
#  13  Road Grade                    104546 non-null  object
#  14  Road Name                     102474 non-null  object
#  15  Cross-Street Name             92746 non-null   object
#  16  Off-Road Description          15254 non-null   object
#  17  Municipality                  10491 non-null   object
#  18  Related Non-Motorist          6814 non-null    object
#  19  At Fault                      120440 non-null  object
#  20  Collision Type                119936 non-null  object
#  21  Weather                       112492 non-null  object
#  22  Surface Condition             102721 non-null  object
#  23  Light                         119625 non-null  object
#  24  Traffic Control               101110 non-null  object
#  25  Driver Substance Abuse        104694 non-null  object
#  26  Non-Motorist Substance Abuse  5696 non-null    object
#  27  First Harmful Event           119790 non-null  object
#  28  Second Harmful Event          30348 non-null   object
#  29  Junction                      90859 non-null   object
#  30  Intersection Type             54626 non-null   object
#  31  Road Alignment                104764 non-null  object
#  32  Road Condition                99864 non-null   object
#  33  Road Division                 103984 non-null  object
#  34  Latitude                      120440 non-null  float64
#  35  Longitude                     120440 non-null  float64
#  36  Location                      120440 non-null  object
# dtypes: float64(2), object(35)
# memory usage: 34.0+ MB

# %%
incidents_df.isnull().sum() #checking for missing values
# Out:
# Report Number                        0
# Local Case Number                    0
# Agency Name                          0
# ACRS Report Type                     0
# Crash Date/Time                      0
# Hit/Run                           4354
# Route Type                       15925
# Lane Direction                   15324
# Lane Type                        90876
# Number of Lanes                  12339
# Direction                        15266
# Distance                         13403
# Distance Unit                    12327
# Road Grade                       15894
# Road Name                        17966
# Cross-Street Name                27694
# Off-Road Description            105186
# Municipality                    109949
# Related Non-Motorist            113626
# At Fault                             0
# Collision Type                     504
# Weather                           7948
# Surface Condition                17719
# Light                              815
# Traffic Control                  19330
# Driver Substance Abuse           15746
# Non-Motorist Substance Abuse    114744
# First Harmful Event                650
# Second Harmful Event             90092
# Junction                         29581
# Intersection Type                65814
# Road Alignment                   15676
# Road Condition                   20576
# Road Division                    16456
# Latitude                             0
# Longitude                            0
# Location                             0
# dtype: int64

# %%
incidents_df.drop(columns=['Latitude','Longitude', 'Location']).describe() #descriptive statistics only for the categorical columns
# Out:
#        Report Number Local Case Number               Agency Name  \
# count         120440            120440                    120440
# unique        120440            120325                        10
# top      MCP11520005         220044049  Montgomery County Police
# freq               1                 2                     78093
#
#              ACRS Report Type         Crash Date/Time Hit/Run  \
# count                  120440                  120440  116086
# unique                      3                  117493       2
# top     Property Damage Crash  05/22/2015 09:55:00 PM      No
# freq                    79547                       5   97535
#
#               Route Type Lane Direction Lane Type  Number of Lanes  ...  \
# count             104515         105116     29564         108101.0  ...
# unique                19             39       210            119.0  ...
# top     Maryland (State)          North    Lane 1              2.0  ...
# freq               39121          25905      8634          25628.0  ...
#
#        Traffic Control  Driver Substance Abuse Non-Motorist Substance Abuse  \
# count           101110                  104694                         5696
# unique              85                     115                           27
# top        NO CONTROLS           NONE DETECTED                NONE DETECTED
# freq             41605                   60777                         3812
#
#        First Harmful Event Second Harmful Event      Junction  \
# count               119790                30348         90859
# unique                  67                   64            22
# top          OTHER VEHICLE        OTHER VEHICLE  INTERSECTION
# freq                 66578                12119         32164
#
#             Intersection Type Road Alignment Road Condition  \
# count                   54626         104764          99864
# unique                     11             12             21
# top     FOUR-WAY INTERSECTION       STRAIGHT     NO DEFECTS
# freq                    30613          74048          80463
#
#                                     Road Division
# count                                      103984
# unique                                         36
# top     TWO-WAY, DIVIDED, POSITIVE MEDIAN BARRIER
# freq                                        39861
#
# [4 rows x 34 columns]

# %% [markdown]
# ### Creating simple countplots to explore important columns that I'll use in my analysis

# %%
plt.figure(figsize=(11,5))
p3 = sn.countplot(y="Light", data = incidents_df)
plt.title("Light Conditions of car collisions in MoCO")
plt.xlabel("Number of Collisions")
for container in p3.containers:       #to display the actual values with commas next to the bar graphs
    p3.bar_label(container, fmt= '{:,.0f}')
plt.show()

# %%
plt.figure(figsize=(11,5))
p4 = sn.countplot(y="Weather", data = incidents_df)
plt.title("Weather Conditions of car collisions in MoCO")
plt.xlabel("Number of Collisions")
for container in p4.containers:       #to display the actual values with commas next to the bar graphs
    p4.bar_label(container, fmt= '{:,.0f}')
plt.show()

# %%
plt.figure(figsize=(11,5))
p5 = sn.countplot(y="Surface Condition", data = incidents_df)
plt.title("Road surface conditions of car collisions in MoCO")
plt.xlabel("Number of Collisions")
for container in p5.containers:       #to display the actual values with commas next to the bar graphs
    p5.bar_label(container, fmt= '{:,.0f}')
plt.show()

# %% [markdown]
# These three exploratory countplots alongside others, show some of the columns that have to be cleaned. To clean them, I will make the entire values of such  columns lowercase to eliminate different versions of the same categorical value

# %%
cols_to_clean = ['Light', 'Weather', 'Surface Condition', 'Collision Type']
for col in cols_to_clean:
  incidents_df[col] = incidents_df[col].str.lower()

# %% [markdown]
# To show the effect of the cleaning, I will make the weather condition count plot again. As we can see below, this was successfull. For example, the two versions of the value "clear" added up to 83,000. In other terms, the number of distinct categorical values for the weather column dropped to 17 from 23.

# %%
plt.figure(figsize=(11,5))
p4 = sn.countplot(y="Weather", data = incidents_df)
plt.title("Weather Conditions(cleaned columns) of car collisions in MoCO")
plt.xlabel("Number of Collisions")
for container in p4.containers:       #to display the actual values with commas next to the bar graphs
    p4.bar_label(container, fmt= '{:,.0f}')
plt.show()

# %% [markdown]
# ###Loading in and exploring the Drivers datset

# %%
drivers_df = pd.read_csv('Crash_Reporting_Drivers_Data_20260407.csv') #loading in the second dataset and checking the first few lines
drivers_df.head()
# Out:
# /tmp/ipykernel_9106/3988527414.py:1: DtypeWarning: Columns (1,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   drivers_df = pd.read_csv('Crash_Reporting_Drivers_Data_20260407.csv') #loading in the second dataset and checking the first few lines
#   Report Number Local Case Number   Agency Name       ACRS Report Type  \
# 0   MCP26510051         260013422    MONTGOMERY  Property Damage Crash
# 1    EJ78880091         260013399  GAITHERSBURG  Property Damage Crash
# 2   MCP235800FK         260013346    MONTGOMERY  Property Damage Crash
# 3   MCP235800FK         260013346    MONTGOMERY  Property Damage Crash
# 4   MCP320000HF         260013348    MONTGOMERY  Property Damage Crash
#
#           Crash Date/Time            Route Type          Road Name  \
# 0  03/28/2026 09:10:00 PM  Other Public Roadway  QUAIL VALLEY BLVD
# 1  03/28/2026 06:52:00 PM                   NaN                NaN
# 2  03/28/2026 12:00:00 PM           Local Route       RIDGEROCK LA
# 3  03/28/2026 12:00:00 PM           Local Route       RIDGEROCK LA
# 4  03/28/2026 11:27:00 AM                   NaN                NaN
#
#   Cross-Street Name                               Off-Road Description  \
# 0               NaN                                                NaN
# 1               NaN  Parking Aisle        PARKING LOT OF 394 N SUMM...
# 2    EXECUTIVE BLVD                                                NaN
# 3    EXECUTIVE BLVD                                                NaN
# 4               NaN  Parking Lot Way        PARKING LOT IN FRONT OF...
#
#   Municipality  ... Vehicle Going Dir Speed Limit Driverless Vehicle  \
# 0          NaN  ...        Southbound          25                 No
# 1          NaN  ...           Unknown           0                 No
# 2          NaN  ...               NaN          35                 No
# 3          NaN  ...               NaN          35                 No
# 4          NaN  ...         Westbound           0                 No
#
#   Parked Vehicle Vehicle Year Vehicle Make Vehicle Model   Latitude  \
# 0             No         2005         FORD       MUSTANG  39.167809
# 1             No         2004        HONDA         PILOT  39.150114
# 2             No         2018     INFINITI          Q70L  39.043276
# 3             No         2009       NISSAN         VERSA  39.043276
# 4             No         2012      HYUNDAI        SONATA  39.017845
#
#    Longitude                         Location
# 0 -77.182975       (39.1678095, -77.18297467)
# 1 -77.191244      (39.15011419, -77.19124427)
# 2 -77.114795      (39.04327621, -77.11479486)
# 3 -77.114795      (39.04327621, -77.11479486)
# 4 -77.208213      (39.01784503, -77.20821304)
#
# [5 rows x 39 columns]

# %%
drivers_df.info() #checking the dimesions and basic info on the dataset columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212210 entries, 0 to 212209
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Report Number                  212210 non-null  object
#  1   Local Case Number              212210 non-null  object
#  2   Agency Name                    212210 non-null  object
#  3   ACRS Report Type               212210 non-null  object
#  4   Crash Date/Time                212210 non-null  object
#  5   Route Type                     191423 non-null  object
#  6   Road Name                      187532 non-null  object
#  7   Cross-Street Name              170776 non-null  object
#  8   Off-Road Description           19745 non-null   object
#  9   Municipality                   19126 non-null   object
#  10  Related Non-Motorist           6918 non-null    object
#  11  Collision Type                 211625 non-null  object
#  12  Weather                        198854 non-null  object
#  13  Surface Condition              188070 non-null  object
#  14  Light                          210765 non-null  object
#  15  Traffic Control                182974 non-null  object
#  16  Driver Substance Abuse         180890 non-null  object
#  17  Non-Motorist Substance Abuse   5772 non-null    object
#  18  Person ID                      212210 non-null  object
#  19  Driver At Fault                212210 non-null  object
#  20  Injury Severity                209435 non-null  object
#  21  Circumstance                   41351 non-null   object
#  22  Driver Distracted By           209238 non-null  object
#  23  Drivers License State          197709 non-null  object
#  24  Vehicle ID                     212210 non-null  object
#  25  Vehicle Damage Extent          211894 non-null  object
#  26  Vehicle First Impact Location  212054 non-null  object
#  27  Vehicle Body Type              208973 non-null  object
#  28  Vehicle Movement               210491 non-null  object
#  29  Vehicle Going Dir              202427 non-null  object
#  30  Speed Limit                    212210 non-null  int64
#  31  Driverless Vehicle             212210 non-null  object
#  32  Parked Vehicle                 210684 non-null  object
#  33  Vehicle Year                   212210 non-null  int64
#  34  Vehicle Make                   211038 non-null  object
#  35  Vehicle Model                  210996 non-null  object
#  36  Latitude                       212210 non-null  float64
#  37  Longitude                      212210 non-null  float64
#  38  Location                       212210 non-null  object
# dtypes: float64(2), int64(2), object(35)
# memory usage: 63.1+ MB

# %%
drivers_df.isnull().sum() #checking for missing values
# Out:
# Report Number                         0
# Local Case Number                     0
# Agency Name                           0
# ACRS Report Type                      0
# Crash Date/Time                       0
# Route Type                        20787
# Road Name                         24678
# Cross-Street Name                 41434
# Off-Road Description             192465
# Municipality                     193084
# Related Non-Motorist             205292
# Collision Type                      585
# Weather                           13356
# Surface Condition                 24140
# Light                              1445
# Traffic Control                   29236
# Driver Substance Abuse            31320
# Non-Motorist Substance Abuse     206438
# Person ID                             0
# Driver At Fault                       0
# Injury Severity                    2775
# Circumstance                     170859
# Driver Distracted By               2972
# Drivers License State             14501
# Vehicle ID                            0
# Vehicle Damage Extent               316
# Vehicle First Impact Location       156
# Vehicle Body Type                  3237
# Vehicle Movement                   1719
# Vehicle Going Dir                  9783
# Speed Limit                           0
# Driverless Vehicle                    0
# Parked Vehicle                     1526
# Vehicle Year                          0
# Vehicle Make                       1172
# Vehicle Model                      1214
# Latitude                              0
# Longitude                             0
# Location                              0
# dtype: int64

# %%
drivers_df.drop(columns=['Speed Limit', 'Vehicle Year', 'Latitude', 'Longitude', 'Location']).describe() #descriptive statistics for the categorical columns
# Out:
#        Report Number Local Case Number               Agency Name  \
# count         212210            212210                    212210
# unique        119687            119602                        10
# top      MCP229800RC         200022715  Montgomery County Police
# freq              10                10                    138376
#
#              ACRS Report Type         Crash Date/Time        Route Type  \
# count                  212210                  212210            191423
# unique                      3                  116767                19
# top     Property Damage Crash  12/10/2018 06:10:00 PM  Maryland (State)
# freq                   136320                      11             77077
#
#           Road Name Cross-Street Name Off-Road Description Municipality  ...  \
# count        187532            170776                19745        19126  ...
# unique         4815              7550                14092           20  ...
# top     GEORGIA AVE       GEORGIA AVE          PARKING LOT    ROCKVILLE  ...
# freq          11807              2394                  132         9320  ...
#
#                                   Vehicle ID Vehicle Damage Extent  \
# count                                 212210                211894
# unique                                212210                    12
# top     EED35F71-B94E-4225-98D4-3405AEA57D0B             DISABLING
# freq                                       1                 62354
#
#        Vehicle First Impact Location Vehicle Body Type       Vehicle Movement  \
# count                         212054            208973                 210491
# unique                            33                60                     36
# top                    TWELVE OCLOCK     PASSENGER CAR  MOVING CONSTANT SPEED
# freq                           68025            119109                  67240
#
#        Vehicle Going Dir Driverless Vehicle Parked Vehicle Vehicle Make  \
# count             202427             212210         210684       211038
# unique                10                  2              2         1965
# top                North                 No             No       TOYOTA
# freq               47647             211457         207136        30862
#
#        Vehicle Model
# count         210996
# unique          7190
# top               4S
# freq           13753
#
# [4 rows x 34 columns]

# %% [markdown]
# ## Research questions

# %% [markdown]
# ### What was the most common type of car collision incident?
# To answer this question I will make a simple countplot of the "ACRS report type" column from the Incidents data.
# I'm not using Drivers data here becuase each row is a driver in that dataset and there can be multiple drivers involved in a single collision which means the type of report will be repeated for each driver so it will be inaccurate.

# %%
plt.figure(figsize=(13,6))
p1 = sn.countplot(y = "ACRS Report Type", data = incidents_df)
plt.title("Most Common Type of Car Collision Incident in MoCo")
plt.xlabel("Number of Collisions as of 04/03/2026")
for container in p1.containers:    #to display the actual values with commas next to the bar graphs
    p1.bar_label(container, fmt='{:,.0f}')
plt.show()

# %% [markdown]
# ### Which roads have seen the most collision incidents?
# I will make a simple countplot to answer this question. To make it slightly different from the inital version, I will add the factor of collision type.

# %%
top10_roads = incidents_df[incidents_df['Road Name'].isin(incidents_df['Road Name'].value_counts().head(10).index)]
plt.figure(figsize=(14,9))
p2 = sn.countplot(y = "Road Name", data = top10_roads, hue='ACRS Report Type',palette=['#0516ad', '#c7c706', '#ad0505'], order = top10_roads["Road Name"].value_counts().index)
plt.title("Top 10 Roads with the Most Car Collision Incidents in MoCo")
plt.xlabel("Number of Collisions as of 04/03/26")
for container in p2.containers:       #to display the actual values with commas next to the bar graphs
    p2.bar_label(container, fmt='{:,.0f}')
plt.show()
